# %% [markdown]
# # Dogs vs Cats
# ## Kaggle Dataset의 전부를 이용한 개, 고양이 구분
# ### Dog Image: 12,500개, Cat Image: 12,500개, 총 25,000개
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp drive/MyDrive/Colab\ Notebooks/train.zip .

# %%
# !unzip -qq train.zip -d dogs-vs-cats

# %%
# !pwd
# Out:
# /content

# %%
# !ls -l dogs-vs-cats/
# Out:
# total 768
# drwxr-xr-x 2 root root 782336 Sep 20  2013 train

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# seed 값 설정
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path='dogs-vs-cats/train'

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
## Definition to load all our dog images
def load_dogs():
    print('Loading all dog images\n')
    dog_path = os.path.join(path, 'dog*')
    for dog_img in glob(dog_path):
        dog = cv2.imread(dog_img)
        dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
        dog = cv2.resize(dog, (ROW, COL))
        dog = image.img_to_array(dog)
        dogs.append(dog)
    print('All dog images loaded')

# %%
## Definition to load all our cat images
def load_cats():
    print('Loading all cat images\n')
    cat_path = os.path.join(path, 'cat*')
    for cat_img in glob(cat_path):
        cat = cv2.imread(cat_img)
        cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
        cat = cv2.resize(cat, (ROW, COL))
        cat = image.img_to_array(cat)
        cats.append(cat)
    print('All cat images loaded')

# %%
## in case we want to see if our images was saved correctly in arrays we can use those codes
def show_dogs():
    plt.figure(figsize=(12,4))    
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = image.array_to_img(random.choice(dogs))
        plt.imshow(img, cmap=plt.get_cmap('gray'))
        
        plt.axis('off')
        plt.title(f'Supposed to be a {classes[0]}')        
    plt.show()

# %%
def show_cats():
    plt.figure(figsize=(12,4))
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = image.array_to_img(random.choice(cats))
        plt.imshow(img, cmap=plt.get_cmap('gray'))

        plt.axis('off')
        plt.title(f'Supposed to be a {classes[1]}')
    plt.show()

# %%
load_dogs()
# Out:
# Loading all dog images
#
# All dog images loaded

# %%
load_cats()
# Out:
# Loading all cat images
#
# All cat images loaded

# %%
classes = ['dog', 'cat']

# %%
show_dogs()

# %%
show_cats()

# %%
## just change the labels for 0 and 1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X = np.concatenate((dogs, cats), axis=0)
y = np.concatenate((y_dogs, y_cats), axis=0)

# %%
X.shape, y.shape
# Out:
# ((25000, 96, 96, 1), (25000,))

# %%
IMG_CHANNEL = 1
BATCH_SIZE = 128
N_EPOCH = 30
VERBOSE = 2
VALIDAION_SPLIT = 0.2
OPTIM = Adam()
N_CLASSES = len(classes)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=seed
)

# %%
## One-Hot Encoding
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, N_CLASSES)
y_test = to_categorical(y_test, N_CLASSES)

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, IMG_CHANNEL), activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(N_CLASSES, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 18,940,898
# Trainable params: 18,940,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=OPTIM, metrics=['accuracy'])

# %%
## to save checkpoint to use latter
modelpath = 'model/dogs_vs_cats_redux_checkpoint.h5'
checkpoint = ModelCheckpoint(filepath=modelpath, save_best_only=True, verbose=1)

# %%
history = model.fit(X_train, y_train, 
                    batch_size=BATCH_SIZE, epochs=N_EPOCH, 
                    validation_split=VALIDAION_SPLIT,
                    verbose=VERBOSE, callbacks=[checkpoint])
# Out:
# Epoch 1/30
# 125/125 - 17s - loss: 0.6989 - accuracy: 0.5486 - val_loss: 0.6683 - val_accuracy: 0.5765
#
# Epoch 00001: val_loss improved from inf to 0.66831, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 2/30
# 125/125 - 9s - loss: 0.6023 - accuracy: 0.6666 - val_loss: 0.5534 - val_accuracy: 0.7100
#
# Epoch 00002: val_loss improved from 0.66831 to 0.55342, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 3/30
# 125/125 - 9s - loss: 0.5443 - accuracy: 0.7237 - val_loss: 0.5182 - val_accuracy: 0.7350
#
# Epoch 00003: val_loss improved from 0.55342 to 0.51824, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 4/30
# 125/125 - 9s - loss: 0.4873 - accuracy: 0.7680 - val_loss: 0.4943 - val_accuracy: 0.7535
#
# Epoch 00004: val_loss improved from 0.51824 to 0.49429, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 5/30
# 125/125 - 9s - loss: 0.4348 - accuracy: 0.7981 - val_loss: 0.4341 - val_accuracy: 0.8037
#
# Epoch 00005: val_loss improved from 0.49429 to 0.43413, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 6/30
# 125/125 - 10s - loss: 0.4054 - accuracy: 0.8123 - val_loss: 0.4212 - val_accuracy: 0.8098
#
# Epoch 00006: val_loss improved from 0.43413 to 0.42117, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 7/30
# 125/125 - 10s - loss: 0.3683 - accuracy: 0.8332 - val_loss: 0.4019 - val_accuracy: 0.8130
#
# Epoch 00007: val_loss improved from 0.42117 to 0.40192, saving model to model/dogs_vs_cats_redux_checkpoint.h5
# Epoch 8/30
# 125/125 - 10s - loss: 0.3191 - accuracy: 0.8614 - val_loss: 0.4081 - val_accuracy: 0.8217
#
# Epoch 00008: val_loss did not improve from 0.40192
# Epoch 9/30
# 125/125 - 10s - loss: 0.2927 - accuracy: 0.8734 - val_loss: 0.4255 - val_accuracy: 0.8173
#
# Epoch 00009: val_loss did not improve from 0.40192
# Epoch 10/30
# 125/125 - 10s - loss: 0.2527 - accuracy: 0.8919 - val_loss: 0.4385 - val_accuracy: 0.8255
#
# Epoch 00010: val_loss did not improve from 0.40192
# Epoch 11/30
# 125/125 - 10s - loss: 0.2102 - accuracy: 0.9122 - val_loss: 0.4993 - val_accuracy: 0.8155
#
# Epoch 00011: val_loss did not improve from 0.40192
# Epoch 12/30
# 125/125 - 10s - loss: 0.1779 - accuracy: 0.9283 - val_loss: 0.4806 - val_accuracy: 0.8170
#
# Epoch 00012: val_loss did not improve from 0.40192
# Epoch 13/30
# 125/125 - 10s - loss: 0.1471 - accuracy: 0.9438 - val_loss: 0.5214 - val_accuracy: 0.8220
#
# Epoch 00013: val_loss did not improve from 0.40192
# Epoch 14/30
# 125/125 - 10s - loss: 0.1195 - accuracy: 0.9539 - val_loss: 0.5615 - val_accuracy: 0.8223
#
# Epoch 00014: val_loss did not improve from 0.40192
# Epoch 15/30
# 125/125 - 10s - loss: 0.1030 - accuracy: 0.9632 - val_loss: 0.5536 - val_accuracy: 0.8238
#
# Epoch 00015: val_loss did not improve from 0.40192
# Epoch 16/30
# 125/125 - 10s - loss: 0.0871 - accuracy: 0.9672 - val_loss: 0.5772 - val_accuracy: 0.8248
#
# Epoch 00016: val_loss did not improve from 0.40192
# Epoch 17/30
# 125/125 - 10s - loss: 0.0740 - accuracy: 0.9731 - val_loss: 0.6823 - val_accuracy: 0.8240
#
# Epoch 00017: val_loss did not improve from 0.40192
# Epoch 18/30
# 125/125 - 10s - loss: 0.0645 - accuracy: 0.9783 - val_loss: 0.6482 - val_accuracy: 0.8263
#
# Epoch 00018: val_loss did not improve from 0.40192
# Epoch 19/30
# 125/125 - 10s - loss: 0.0578 - accuracy: 0.9798 - val_loss: 0.7050 - val_accuracy: 0.8325
#
# Epoch 00019: val_loss did not improve from 0.40192
# Epoch 20/30
# 125/125 - 10s - loss: 0.0514 - accuracy: 0.9816 - val_loss: 0.7977 - val_accuracy: 0.8292
#
# Epoch 00020: val_loss did not improve from 0.40192
# Epoch 21/30
# 125/125 - 10s - loss: 0.0598 - accuracy: 0.9785 - val_loss: 0.6738 - val_accuracy: 0.8278
#
# Epoch 00021: val_loss did not improve from 0.40192
# Epoch 22/30
# 125/125 - 10s - loss: 0.0462 - accuracy: 0.9844 - val_loss: 0.8878 - val_accuracy: 0.8288
#
# Epoch 00022: val_loss did not improve from 0.40192
# Epoch 23/30
# 125/125 - 10s - loss: 0.0420 - accuracy: 0.9852 - val_loss: 0.7519 - val_accuracy: 0.8257
#
# Epoch 00023: val_loss did not improve from 0.40192
# Epoch 24/30
# 125/125 - 10s - loss: 0.0415 - accuracy: 0.9860 - val_loss: 0.8033 - val_accuracy: 0.8365
#
# Epoch 00024: val_loss did not improve from 0.40192
# Epoch 25/30
# 125/125 - 10s - loss: 0.0349 - accuracy: 0.9877 - val_loss: 0.8007 - val_accuracy: 0.8275
#
# Epoch 00025: val_loss did not improve from 0.40192
# Epoch 26/30
# 125/125 - 10s - loss: 0.0352 - accuracy: 0.9885 - val_loss: 0.7521 - val_accuracy: 0.8315
#
# Epoch 00026: val_loss did not improve from 0.40192
# Epoch 27/30
# 125/125 - 10s - loss: 0.0302 - accuracy: 0.9894 - val_loss: 0.8882 - val_accuracy: 0.8325
#
# Epoch 00027: val_loss did not improve from 0.40192
# Epoch 28/30
# 125/125 - 10s - loss: 0.0418 - accuracy: 0.9858 - val_loss: 0.8623 - val_accuracy: 0.8200
#
# Epoch 00028: val_loss did not improve from 0.40192
# Epoch 29/30
# 125/125 - 10s - loss: 0.0295 - accuracy: 0.9898 - val_loss: 0.8378 - val_accuracy: 0.8320
#
# Epoch 00029: val_loss did not improve from 0.40192
# Epoch 30/30
# 125/125 - 10s - loss: 0.0359 - accuracy: 0.9874 - val_loss: 0.7209 - val_accuracy: 0.8338
#
# Epoch 00030: val_loss did not improve from 0.40192

# %%
acc = model.evaluate(X_test, y_test, verbose=2)[1]
print('MODEL ACCURACY: %.5f' % acc)
# Out:
# 157/157 - 1s - loss: 0.7198 - accuracy: 0.8364
# MODEL ACCURACY: 0.83640

# %%
from tensorflow.keras.models import load_model
best_model = load_model(modelpath)
acc = best_model.evaluate(X_test, y_test, verbose=2)[1]
print('Best model accuracy: %.5f' % acc)
# Out:
# 157/157 - 1s - loss: 0.3986 - accuracy: 0.8236
# Best model accuracy: 0.82360

# %%
# 검증셋
y_vloss = history.history['val_loss']
y_vacc = history.history['val_accuracy']

# 학습셋
y_loss = history.history['loss']
y_acc = history.history['accuracy']

# %%
x_len = np.arange(1, len(y_loss)+1)
fig, ax0 = plt.subplots(figsize=(10,8))
ax1 = ax0.twinx()
ax0.plot(x_len, y_loss, c="blue", label='train set loss')
ax0.plot(x_len, y_vloss, c="red", label='valid set loss')
ax0.set_ylabel('loss')
ax1.plot(x_len, y_acc, c="darkgreen", label='train set acc')
ax1.plot(x_len, y_vacc, c="magenta", label='valid set acc')
ax1.set_ylabel('accuracy')
ax0.set_xlabel('epoch')
ax0.legend(loc='lower center')
ax1.legend(loc='upper center')
plt.grid()
plt.show()
