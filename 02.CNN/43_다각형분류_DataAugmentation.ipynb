# %% [markdown]
# # 원, 삼각형, 사각형 구분하기
# - 어려운 테스트 문제를 데이터 부풀리기를 이용한 경우

# %%
import numpy as np
import tensorflow as tf
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## 데이터셋 부풀리기

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1/255.0,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.5,
    zoom_range=[0.8, 2.0],
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# %%
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
img = load_img('hard_handwriting_shape/train/triangle/triangle001.png')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)

# %%
i = 0
for batch in train_datagen.flow(x, batch_size=1, save_to_dir='preview',
                                save_prefix='tri', save_format='png'):
    i += 1
    if i > 20:
        break

# %%
train_generator = train_datagen.flow_from_directory(
    'hard_handwriting_shape/train',
    target_size=(24,24),
    batch_size=3,
    class_mode='categorical'
)
# Out:
# Found 45 images belonging to 3 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1/255.)
test_generator = test_datagen.flow_from_directory(
    'hard_handwriting_shape/test',
    target_size=(24,24),
    batch_size=3,
    class_mode='categorical'
)
# Out:
# Found 15 images belonging to 3 classes.

# %% [markdown]
# ## 모델 정의/설정

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
model = Sequential([ 
    Conv2D(32, (3,3), input_shape=(24,24,3), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 22, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               819328
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 839,107
# Trainable params: 839,107
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']
)

# %% [markdown]
# ## 모델 학습
# - 첫번째 인자 : 훈련데이터셋을 제공할 제네레이터를 지정. 본 예제에서는 앞서 생성한 train_generator으로 지정.
# - steps_per_epoch : 한 epoch에 사용한 스텝 수를 지정. 총 45개의 훈련 샘플이 있고 배치사이즈가 3이므로 15 스텝으로 지정.
# - epochs : 전체 훈련 데이터셋에 대해 학습 반복 횟수를 지정. 50번을 반복적으로 학습.
# - validation_data : 검증데이터셋을 제공할 제네레이터를 지정. 본 예제에서는 앞서 생성한 test_generator으로 지정.
# - validation_steps : 한 epoch 종료 시 마다 검증할 때 사용되는 검증 스텝 수를 지정. 총 15개의 검증 샘플이 있고 배치사이즈가 3이므로 5 스텝으로 지정.

# %%
model.fit(
        train_generator,
        steps_per_epoch=15,
        epochs=200,
        validation_data=test_generator,
        validation_steps=5,
        verbose=2
)
# Out:
# Epoch 1/200
# 15/15 - 0s - loss: 1.0085 - accuracy: 0.5111 - val_loss: 1.0370 - val_accuracy: 0.5333
# Epoch 2/200
# 15/15 - 0s - loss: 0.7472 - accuracy: 0.6667 - val_loss: 1.4048 - val_accuracy: 0.4000
# Epoch 3/200
# 15/15 - 0s - loss: 0.6623 - accuracy: 0.6667 - val_loss: 1.5149 - val_accuracy: 0.4000
# Epoch 4/200
# 15/15 - 0s - loss: 0.5807 - accuracy: 0.7778 - val_loss: 1.5868 - val_accuracy: 0.5333
# Epoch 5/200
# 15/15 - 0s - loss: 0.5664 - accuracy: 0.7556 - val_loss: 1.5774 - val_accuracy: 0.5333
# Epoch 6/200
# 15/15 - 0s - loss: 0.3754 - accuracy: 0.8889 - val_loss: 2.2055 - val_accuracy: 0.5333
# Epoch 7/200
# 15/15 - 0s - loss: 0.4358 - accuracy: 0.8000 - val_loss: 2.2187 - val_accuracy: 0.6000
# Epoch 8/200
# 15/15 - 0s - loss: 0.2898 - accuracy: 0.8889 - val_loss: 2.4923 - val_accuracy: 0.4667
# Epoch 9/200
# 15/15 - 0s - loss: 0.2323 - accuracy: 0.9111 - val_loss: 3.2512 - val_accuracy: 0.5333
# Epoch 10/200
# 15/15 - 0s - loss: 0.2744 - accuracy: 0.8889 - val_loss: 2.3387 - val_accuracy: 0.4667
# Epoch 11/200
# 15/15 - 0s - loss: 0.3642 - accuracy: 0.8667 - val_loss: 2.9137 - val_accuracy: 0.5333
# Epoch 12/200
# 15/15 - 0s - loss: 0.3802 - accuracy: 0.9111 - val_loss: 2.8780 - val_accuracy: 0.5333
# Epoch 13/200
# 15/15 - 0s - loss: 0.2085 - accuracy: 0.9333 - val_loss: 2.1656 - val_accuracy: 0.5333
# Epoch 14/200
# 15/15 - 0s - loss: 0.1599 - accuracy: 0.9778 - val_loss: 1.9601 - val_accuracy: 0.6667
# Epoch 15/200
# 15/15 - 0s - loss: 0.1950 - accuracy: 0.9333 - val_loss: 3.2452 - val_accuracy: 0.5333
# Epoch 16/200
# 15/15 - 0s - loss: 0.1248 - accuracy: 0.9778 - val_loss: 2.0690 - val_accuracy: 0.5333
# Epoch 17/200
# 15/15 - 0s - loss: 0.1565 - accuracy: 0.9333 - val_loss: 1.9136 - val_accuracy: 0.6667
# Epoch 18/200
# 15/15 - 0s - loss: 0.1510 - accuracy: 0.9556 - val_loss: 1.5173 - val_accuracy: 0.6667
# Epoch 19/200
# 15/15 - 0s - loss: 0.1015 - accuracy: 0.9556 - val_loss: 2.0581 - val_accuracy: 0.6000
# Epoch 20/200
# 15/15 - 0s - loss: 0.1301 - accuracy: 0.9778 - val_loss: 1.8171 - val_accuracy: 0.6000
# Epoch 21/200
# 15/15 - 0s - loss: 0.0987 - accuracy: 0.9556 - val_loss: 1.4737 - val_accuracy: 0.7333
# Epoch 22/200
# 15/15 - 0s - loss: 0.1969 - accuracy: 0.9333 - val_loss: 2.7948 - val_accuracy: 0.6667
# Epoch 23/200
# 15/15 - 0s - loss: 0.0258 - accuracy: 1.0000 - val_loss: 2.6168 - val_accuracy: 0.6667
# Epoch 24/200
# 15/15 - 0s - loss: 0.2815 - accuracy: 0.9333 - val_loss: 2.4139 - val_accuracy: 0.6667
# Epoch 25/200
# 15/15 - 0s - loss: 0.0520 - accuracy: 0.9778 - val_loss: 1.9397 - val_accuracy: 0.6667
# Epoch 26/200
# 15/15 - 0s - loss: 0.0716 - accuracy: 0.9778 - val_loss: 1.9231 - val_accuracy: 0.7333
# Epoch 27/200
# 15/15 - 0s - loss: 0.0371 - accuracy: 1.0000 - val_loss: 2.2163 - val_accuracy: 0.7333
# Epoch 28/200
# 15/15 - 0s - loss: 0.0538 - accuracy: 0.9778 - val_loss: 2.6538 - val_accuracy: 0.6667
# Epoch 29/200
# 15/15 - 0s - loss: 0.0556 - accuracy: 0.9778 - val_loss: 2.5960 - val_accuracy: 0.6667
# Epoch 30/200
# 15/15 - 0s - loss: 0.2054 - accuracy: 0.9111 - val_loss: 4.6484 - val_accuracy: 0.5333
# Epoch 31/200
# 15/15 - 0s - loss: 0.0282 - accuracy: 1.0000 - val_loss: 2.8795 - val_accuracy: 0.6667
# Epoch 32/200
# 15/15 - 0s - loss: 0.1791 - accuracy: 0.9333 - val_loss: 2.2201 - val_accuracy: 0.6667
# Epoch 33/200
# 15/15 - 0s - loss: 0.0677 - accuracy: 0.9556 - val_loss: 1.8410 - val_accuracy: 0.7333
# Epoch 34/200
# 15/15 - 0s - loss: 0.1237 - accuracy: 0.9556 - val_loss: 3.0917 - val_accuracy: 0.6000
# Epoch 35/200
# 15/15 - 0s - loss: 0.0860 - accuracy: 0.9778 - val_loss: 2.3940 - val_accuracy: 0.6667
# Epoch 36/200
# 15/15 - 0s - loss: 0.0372 - accuracy: 0.9778 - val_loss: 2.8546 - val_accuracy: 0.6667
# Epoch 37/200
# 15/15 - 0s - loss: 0.0422 - accuracy: 0.9778 - val_loss: 3.0427 - val_accuracy: 0.6667
# Epoch 38/200
# 15/15 - 0s - loss: 0.0652 - accuracy: 0.9778 - val_loss: 2.8225 - val_accuracy: 0.6667
# Epoch 39/200
# 15/15 - 0s - loss: 0.0673 - accuracy: 0.9778 - val_loss: 1.9501 - val_accuracy: 0.6667
# Epoch 40/200
# 15/15 - 0s - loss: 0.1682 - accuracy: 0.9778 - val_loss: 5.2987 - val_accuracy: 0.4667
# Epoch 41/200
# 15/15 - 0s - loss: 0.2164 - accuracy: 0.9333 - val_loss: 0.6940 - val_accuracy: 0.8667
# Epoch 42/200
# 15/15 - 0s - loss: 0.0449 - accuracy: 1.0000 - val_loss: 1.3684 - val_accuracy: 0.8667
# Epoch 43/200
# 15/15 - 0s - loss: 0.0981 - accuracy: 0.9556 - val_loss: 0.5953 - val_accuracy: 0.8000
# Epoch 44/200
# 15/15 - 0s - loss: 0.0899 - accuracy: 0.9778 - val_loss: 1.6090 - val_accuracy: 0.7333
# Epoch 45/200
# 15/15 - 0s - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.2130 - val_accuracy: 0.7333
# Epoch 46/200
# 15/15 - 0s - loss: 0.1346 - accuracy: 0.9333 - val_loss: 3.3420 - val_accuracy: 0.6000
# Epoch 47/200
# 15/15 - 0s - loss: 0.0629 - accuracy: 0.9778 - val_loss: 1.2155 - val_accuracy: 0.7333
# Epoch 48/200
# 15/15 - 0s - loss: 0.0792 - accuracy: 0.9556 - val_loss: 1.6723 - val_accuracy: 0.6667
# Epoch 49/200
# 15/15 - 0s - loss: 0.2836 - accuracy: 0.9111 - val_loss: 2.1214 - val_accuracy: 0.6000
# Epoch 50/200
# 15/15 - 0s - loss: 0.1072 - accuracy: 0.9778 - val_loss: 1.5932 - val_accuracy: 0.7333
# Epoch 51/200
# 15/15 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 1.2701 - val_accuracy: 0.8000
# Epoch 52/200
# 15/15 - 0s - loss: 0.0199 - accuracy: 1.0000 - val_loss: 1.3941 - val_accuracy: 0.7333
# Epoch 53/200
# 15/15 - 0s - loss: 0.0369 - accuracy: 1.0000 - val_loss: 1.3543 - val_accuracy: 0.7333
# Epoch 54/200
# 15/15 - 0s - loss: 0.0242 - accuracy: 1.0000 - val_loss: 2.0591 - val_accuracy: 0.6000
# Epoch 55/200
# 15/15 - 0s - loss: 0.1501 - accuracy: 0.9556 - val_loss: 1.0695 - val_accuracy: 0.7333
# Epoch 56/200
# 15/15 - 0s - loss: 0.2283 - accuracy: 0.9778 - val_loss: 0.5586 - val_accuracy: 0.8667
# Epoch 57/200
# 15/15 - 0s - loss: 0.1664 - accuracy: 0.9111 - val_loss: 1.0350 - val_accuracy: 0.8000
# Epoch 58/200
# 15/15 - 0s - loss: 0.1314 - accuracy: 0.9556 - val_loss: 1.2979 - val_accuracy: 0.8000
# Epoch 59/200
# 15/15 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 1.3302 - val_accuracy: 0.8000
# Epoch 60/200
# 15/15 - 0s - loss: 0.0846 - accuracy: 0.9556 - val_loss: 1.6778 - val_accuracy: 0.8000
# Epoch 61/200
# 15/15 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.7118 - val_accuracy: 0.8000
# Epoch 62/200
# 15/15 - 0s - loss: 0.0810 - accuracy: 0.9778 - val_loss: 1.7800 - val_accuracy: 0.8000
# Epoch 63/200
# 15/15 - 0s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 1.7889 - val_accuracy: 0.8000
# Epoch 64/200
# 15/15 - 0s - loss: 0.1842 - accuracy: 0.9556 - val_loss: 1.4572 - val_accuracy: 0.8000
# Epoch 65/200
# 15/15 - 0s - loss: 0.0233 - accuracy: 1.0000 - val_loss: 1.4466 - val_accuracy: 0.8000
# Epoch 66/200
# 15/15 - 0s - loss: 0.0319 - accuracy: 0.9778 - val_loss: 1.3228 - val_accuracy: 0.8000
# Epoch 67/200
# 15/15 - 0s - loss: 0.1279 - accuracy: 0.9778 - val_loss: 1.4614 - val_accuracy: 0.8667
# Epoch 68/200
# 15/15 - 0s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 2.1381 - val_accuracy: 0.6667
# Epoch 69/200
# 15/15 - 0s - loss: 0.0937 - accuracy: 0.9778 - val_loss: 2.1017 - val_accuracy: 0.6667
# Epoch 70/200
# 15/15 - 0s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 1.7631 - val_accuracy: 0.8000
# Epoch 71/200
# 15/15 - 0s - loss: 0.1100 - accuracy: 0.9556 - val_loss: 2.3962 - val_accuracy: 0.6667
# Epoch 72/200
# 15/15 - 0s - loss: 0.1016 - accuracy: 0.9778 - val_loss: 1.9958 - val_accuracy: 0.7333
# Epoch 73/200
# 15/15 - 0s - loss: 0.0353 - accuracy: 1.0000 - val_loss: 2.6521 - val_accuracy: 0.6000
# Epoch 74/200
# 15/15 - 0s - loss: 0.0491 - accuracy: 0.9778 - val_loss: 2.5058 - val_accuracy: 0.6000
# Epoch 75/200
# 15/15 - 0s - loss: 0.0229 - accuracy: 1.0000 - val_loss: 2.4876 - val_accuracy: 0.6667
# Epoch 76/200
# 15/15 - 0s - loss: 0.0297 - accuracy: 0.9778 - val_loss: 2.4472 - val_accuracy: 0.6667
# Epoch 77/200
# 15/15 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 2.4231 - val_accuracy: 0.6000
# Epoch 78/200
# 15/15 - 0s - loss: 0.0939 - accuracy: 0.9556 - val_loss: 1.9714 - val_accuracy: 0.7333
# Epoch 79/200
# 15/15 - 0s - loss: 0.1983 - accuracy: 0.9333 - val_loss: 2.1469 - val_accuracy: 0.6667
# Epoch 80/200
# 15/15 - 0s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 2.1840 - val_accuracy: 0.6667
# Epoch 81/200
# 15/15 - 0s - loss: 0.0211 - accuracy: 1.0000 - val_loss: 2.2399 - val_accuracy: 0.6667
# Epoch 82/200
# 15/15 - 0s - loss: 0.0367 - accuracy: 0.9778 - val_loss: 2.1034 - val_accuracy: 0.6667
# Epoch 83/200
# 15/15 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.8829 - val_accuracy: 0.7333
# Epoch 84/200
# 15/15 - 0s - loss: 0.2659 - accuracy: 0.9333 - val_loss: 1.6011 - val_accuracy: 0.8000
# Epoch 85/200
# 15/15 - 0s - loss: 0.0427 - accuracy: 1.0000 - val_loss: 1.9595 - val_accuracy: 0.8000
# Epoch 86/200
# 15/15 - 0s - loss: 0.2504 - accuracy: 0.9333 - val_loss: 1.1284 - val_accuracy: 0.8000
# Epoch 87/200
# 15/15 - 0s - loss: 0.0681 - accuracy: 0.9778 - val_loss: 1.4857 - val_accuracy: 0.7333
# Epoch 88/200
# 15/15 - 0s - loss: 0.0249 - accuracy: 1.0000 - val_loss: 1.8848 - val_accuracy: 0.6000
# Epoch 89/200
# 15/15 - 0s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 2.1604 - val_accuracy: 0.6000
# Epoch 90/200
# 15/15 - 0s - loss: 0.0251 - accuracy: 1.0000 - val_loss: 2.2062 - val_accuracy: 0.6000
# Epoch 91/200
# 15/15 - 0s - loss: 0.0324 - accuracy: 1.0000 - val_loss: 1.7953 - val_accuracy: 0.6667
# Epoch 92/200
# 15/15 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.5582 - val_accuracy: 0.7333
# Epoch 93/200
# 15/15 - 0s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 2.2963 - val_accuracy: 0.6667
# Epoch 94/200
# 15/15 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.5438 - val_accuracy: 0.6000
# Epoch 95/200
# 15/15 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 3.5496 - val_accuracy: 0.5333
# Epoch 96/200
# 15/15 - 0s - loss: 0.0528 - accuracy: 0.9778 - val_loss: 1.9030 - val_accuracy: 0.7333
# Epoch 97/200
# 15/15 - 0s - loss: 0.1629 - accuracy: 0.9333 - val_loss: 1.6428 - val_accuracy: 0.8000
# Epoch 98/200
# 15/15 - 0s - loss: 0.0207 - accuracy: 1.0000 - val_loss: 1.6754 - val_accuracy: 0.8000
# Epoch 99/200
# 15/15 - 0s - loss: 0.1475 - accuracy: 0.9556 - val_loss: 2.2448 - val_accuracy: 0.6667
# Epoch 100/200
# 15/15 - 0s - loss: 0.0695 - accuracy: 0.9556 - val_loss: 2.6698 - val_accuracy: 0.6000
# Epoch 101/200
# 15/15 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 3.5999 - val_accuracy: 0.6000
# Epoch 102/200
# 15/15 - 0s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 3.6247 - val_accuracy: 0.6000
# Epoch 103/200
# 15/15 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 3.1891 - val_accuracy: 0.6000
# Epoch 104/200
# 15/15 - 0s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 3.1733 - val_accuracy: 0.6000
# Epoch 105/200
# 15/15 - 0s - loss: 0.0773 - accuracy: 0.9778 - val_loss: 2.5651 - val_accuracy: 0.6667
# Epoch 106/200
# 15/15 - 0s - loss: 0.0470 - accuracy: 0.9778 - val_loss: 3.0986 - val_accuracy: 0.6000
# Epoch 107/200
# 15/15 - 0s - loss: 0.0447 - accuracy: 0.9778 - val_loss: 5.4388 - val_accuracy: 0.4667
# Epoch 108/200
# 15/15 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 4.1367 - val_accuracy: 0.5333
# Epoch 109/200
# 15/15 - 0s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 4.7068 - val_accuracy: 0.5333
# Epoch 110/200
# 15/15 - 0s - loss: 0.0711 - accuracy: 0.9556 - val_loss: 2.4224 - val_accuracy: 0.7333
# Epoch 111/200
# 15/15 - 0s - loss: 0.0406 - accuracy: 0.9778 - val_loss: 2.2578 - val_accuracy: 0.8000
# Epoch 112/200
# 15/15 - 0s - loss: 8.2856e-04 - accuracy: 1.0000 - val_loss: 2.3810 - val_accuracy: 0.7333
# Epoch 113/200
# 15/15 - 0s - loss: 0.0175 - accuracy: 1.0000 - val_loss: 3.1056 - val_accuracy: 0.6667
# Epoch 114/200
# 15/15 - 0s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 3.1918 - val_accuracy: 0.6667
# Epoch 115/200
# 15/15 - 0s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 2.3211 - val_accuracy: 0.8000
# Epoch 116/200
# 15/15 - 0s - loss: 0.1655 - accuracy: 0.9556 - val_loss: 4.0767 - val_accuracy: 0.6000
# Epoch 117/200
# 15/15 - 0s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 6.4063 - val_accuracy: 0.4667
# Epoch 118/200
# 15/15 - 0s - loss: 9.8055e-04 - accuracy: 1.0000 - val_loss: 4.8008 - val_accuracy: 0.5333
# Epoch 119/200
# 15/15 - 0s - loss: 7.5873e-04 - accuracy: 1.0000 - val_loss: 4.6618 - val_accuracy: 0.5333
# Epoch 120/200
# 15/15 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 4.6575 - val_accuracy: 0.6000
# Epoch 121/200
# 15/15 - 0s - loss: 0.1483 - accuracy: 0.9778 - val_loss: 3.0703 - val_accuracy: 0.6667
# Epoch 122/200
# 15/15 - 0s - loss: 0.0510 - accuracy: 0.9778 - val_loss: 2.0316 - val_accuracy: 0.8000
# Epoch 123/200
# 15/15 - 0s - loss: 0.1152 - accuracy: 0.9778 - val_loss: 2.0493 - val_accuracy: 0.7333
# Epoch 124/200
# 15/15 - 0s - loss: 0.0134 - accuracy: 1.0000 - val_loss: 2.5323 - val_accuracy: 0.7333
# Epoch 125/200
# 15/15 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 2.4960 - val_accuracy: 0.7333
# Epoch 126/200
# 15/15 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.4641 - val_accuracy: 0.7333
# Epoch 127/200
# 15/15 - 0s - loss: 0.0931 - accuracy: 0.9778 - val_loss: 2.2737 - val_accuracy: 0.7333
# Epoch 128/200
# 15/15 - 0s - loss: 0.1046 - accuracy: 0.9556 - val_loss: 2.9574 - val_accuracy: 0.6667
# Epoch 129/200
# 15/15 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 2.1379 - val_accuracy: 0.8000
# Epoch 130/200
# 15/15 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.1190 - val_accuracy: 0.8000
# Epoch 131/200
# 15/15 - 0s - loss: 0.0264 - accuracy: 1.0000 - val_loss: 2.1445 - val_accuracy: 0.8000
# Epoch 132/200
# 15/15 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 2.2636 - val_accuracy: 0.8000
# Epoch 133/200
# 15/15 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 2.3234 - val_accuracy: 0.8000
# Epoch 134/200
# 15/15 - 0s - loss: 0.0506 - accuracy: 0.9778 - val_loss: 2.3603 - val_accuracy: 0.8000
# Epoch 135/200
# 15/15 - 0s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 2.0976 - val_accuracy: 0.8000
# Epoch 136/200
# 15/15 - 0s - loss: 0.0891 - accuracy: 0.9778 - val_loss: 2.1467 - val_accuracy: 0.8000
# Epoch 137/200
# 15/15 - 0s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 2.1269 - val_accuracy: 0.8000
# Epoch 138/200
# 15/15 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.1617 - val_accuracy: 0.8000
# Epoch 139/200
# 15/15 - 0s - loss: 0.0249 - accuracy: 0.9778 - val_loss: 2.2338 - val_accuracy: 0.8000
# Epoch 140/200
# 15/15 - 0s - loss: 0.0533 - accuracy: 0.9778 - val_loss: 2.4950 - val_accuracy: 0.7333
# Epoch 141/200
# 15/15 - 0s - loss: 0.0634 - accuracy: 0.9556 - val_loss: 2.1907 - val_accuracy: 0.8000
# Epoch 142/200
# 15/15 - 0s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 2.1763 - val_accuracy: 0.8000
# Epoch 143/200
# 15/15 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 2.6862 - val_accuracy: 0.7333
# Epoch 144/200
# 15/15 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 2.8050 - val_accuracy: 0.7333
# Epoch 145/200
# 15/15 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.0330 - val_accuracy: 0.7333
# Epoch 146/200
# 15/15 - 0s - loss: 0.2065 - accuracy: 0.9556 - val_loss: 2.3468 - val_accuracy: 0.8000
# Epoch 147/200
# 15/15 - 0s - loss: 0.1114 - accuracy: 0.9778 - val_loss: 2.6049 - val_accuracy: 0.6667
# Epoch 148/200
# 15/15 - 0s - loss: 0.2184 - accuracy: 0.9556 - val_loss: 1.4868 - val_accuracy: 0.8000
# Epoch 149/200
# 15/15 - 0s - loss: 0.1510 - accuracy: 0.9333 - val_loss: 2.2301 - val_accuracy: 0.8000
# Epoch 150/200
# 15/15 - 0s - loss: 0.0955 - accuracy: 0.9778 - val_loss: 2.9529 - val_accuracy: 0.6667
# Epoch 151/200
# 15/15 - 0s - loss: 0.0237 - accuracy: 1.0000 - val_loss: 4.0354 - val_accuracy: 0.6000
# Epoch 152/200
# 15/15 - 0s - loss: 0.0485 - accuracy: 0.9778 - val_loss: 2.9776 - val_accuracy: 0.6667
# Epoch 153/200
# 15/15 - 0s - loss: 0.0577 - accuracy: 0.9778 - val_loss: 3.8609 - val_accuracy: 0.6000
# Epoch 154/200
# 15/15 - 0s - loss: 0.0248 - accuracy: 1.0000 - val_loss: 3.7609 - val_accuracy: 0.6000
# Epoch 155/200
# 15/15 - 0s - loss: 0.0686 - accuracy: 0.9778 - val_loss: 5.4474 - val_accuracy: 0.4667
# Epoch 156/200
# 15/15 - 0s - loss: 0.0399 - accuracy: 0.9778 - val_loss: 3.1402 - val_accuracy: 0.6667
# Epoch 157/200
# 15/15 - 0s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 2.8516 - val_accuracy: 0.6667
# Epoch 158/200
# 15/15 - 0s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 2.8549 - val_accuracy: 0.6667
# Epoch 159/200
# 15/15 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.8955 - val_accuracy: 0.7333
# Epoch 160/200
# 15/15 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 2.9726 - val_accuracy: 0.6667
# Epoch 161/200
# 15/15 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.0396 - val_accuracy: 0.6667
# Epoch 162/200
# 15/15 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 3.1228 - val_accuracy: 0.6667
# Epoch 163/200
# 15/15 - 0s - loss: 0.0931 - accuracy: 0.9556 - val_loss: 3.2275 - val_accuracy: 0.6667
# Epoch 164/200
# 15/15 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 3.2335 - val_accuracy: 0.6000
# Epoch 165/200
# 15/15 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 3.1617 - val_accuracy: 0.6000
# Epoch 166/200
# 15/15 - 0s - loss: 0.0656 - accuracy: 0.9556 - val_loss: 2.3123 - val_accuracy: 0.8000
# Epoch 167/200
# 15/15 - 0s - loss: 0.1075 - accuracy: 0.9556 - val_loss: 8.3615 - val_accuracy: 0.4667
# Epoch 168/200
# 15/15 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.9804 - val_accuracy: 0.6000
# Epoch 169/200
# 15/15 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.4970 - val_accuracy: 0.6000
# Epoch 170/200
# 15/15 - 0s - loss: 0.0842 - accuracy: 0.9778 - val_loss: 2.1472 - val_accuracy: 0.7333
# Epoch 171/200
# 15/15 - 0s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.8764 - val_accuracy: 0.8000
# Epoch 172/200
# 15/15 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.9143 - val_accuracy: 0.8000
# Epoch 173/200
# 15/15 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.9582 - val_accuracy: 0.8000
# Epoch 174/200
# 15/15 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 2.0360 - val_accuracy: 0.8000
# Epoch 175/200
# 15/15 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.0848 - val_accuracy: 0.8000
# Epoch 176/200
# 15/15 - 0s - loss: 0.0467 - accuracy: 0.9778 - val_loss: 4.5176 - val_accuracy: 0.6000
# Epoch 177/200
# 15/15 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 4.3664 - val_accuracy: 0.6000
# Epoch 178/200
# 15/15 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.9796 - val_accuracy: 0.6000
# Epoch 179/200
# 15/15 - 0s - loss: 0.0338 - accuracy: 0.9778 - val_loss: 3.5934 - val_accuracy: 0.7333
# Epoch 180/200
# 15/15 - 0s - loss: 0.0635 - accuracy: 0.9556 - val_loss: 2.7839 - val_accuracy: 0.7333
# Epoch 181/200
# 15/15 - 0s - loss: 0.0437 - accuracy: 0.9778 - val_loss: 2.8294 - val_accuracy: 0.6667
# Epoch 182/200
# 15/15 - 0s - loss: 4.0396e-04 - accuracy: 1.0000 - val_loss: 3.0022 - val_accuracy: 0.7333
# Epoch 183/200
# 15/15 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.9903 - val_accuracy: 0.7333
# Epoch 184/200
# 15/15 - 0s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 3.2102 - val_accuracy: 0.6667
# Epoch 185/200
# 15/15 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.4722 - val_accuracy: 0.6000
# Epoch 186/200
# 15/15 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.5710 - val_accuracy: 0.6000
# Epoch 187/200
# 15/15 - 0s - loss: 0.0795 - accuracy: 0.9778 - val_loss: 3.4101 - val_accuracy: 0.6667
# Epoch 188/200
# 15/15 - 0s - loss: 0.0923 - accuracy: 0.9778 - val_loss: 2.9289 - val_accuracy: 0.6667
# Epoch 189/200
# 15/15 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 3.0206 - val_accuracy: 0.6667
# Epoch 190/200
# 15/15 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.0493 - val_accuracy: 0.6667
# Epoch 191/200
# 15/15 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 3.1297 - val_accuracy: 0.7333
# Epoch 192/200
# 15/15 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.1863 - val_accuracy: 0.7333
# Epoch 193/200
# 15/15 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 3.2967 - val_accuracy: 0.6667
# Epoch 194/200
# 15/15 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.3521 - val_accuracy: 0.6667
# Epoch 195/200
# 15/15 - 0s - loss: 6.7007e-04 - accuracy: 1.0000 - val_loss: 3.3601 - val_accuracy: 0.6667
# Epoch 196/200
# 15/15 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.4399 - val_accuracy: 0.6667
# Epoch 197/200
# 15/15 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.4828 - val_accuracy: 0.6667
# Epoch 198/200
# 15/15 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.4738 - val_accuracy: 0.6667
# Epoch 199/200
# 15/15 - 0s - loss: 2.8447e-04 - accuracy: 1.0000 - val_loss: 3.4649 - val_accuracy: 0.6667
# Epoch 200/200
# 15/15 - 0s - loss: 4.2439e-04 - accuracy: 1.0000 - val_loss: 3.4913 - val_accuracy: 0.6667

# %% [markdown]
# ## 모델 평가

# %%
model.evaluate(test_generator, steps=5)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 3.4913 - accuracy: 0.6667
# [3.491260051727295, 0.6666666865348816]
